# %%
#Task 1: Data Preparation
# "You will start by loading the CSV data from the file (using appropriate pandas functions) and checking whether the loaded data is equivalent to the data in the source CSV file.
# Then, you need to clean the data by using the knowledge we taught in the lectures. You need to deal with all the potential issues/errors in the data appropriately (such as: typos, extra whitespaces, sanity checks for impossible values, and missing values etc). "

# Please structure code as follows: 
# always provide one line of comments to explain the purpose of the code, e.g. load the data, checking the equivalent to original data, checking typos (do this for each other types of errors)

# pandas imported
import pandas as pd

# csv stored in an object
auto_file = 'automobile.csv'

# read csv file 
auto = pd.read_csv(auto_file, sep='#', decimal='.', header=None, names= ['symboling','normalized-losses', 'make',
'fuel-type', 'aspiration', 'num-of-doors', 'body-style', 'drive-wheels','engine-location', 'wheel-base', 'length', 'width',
'height', 'curb-weight', 'engine-type', 'num-of-cylinders', 'engine-size', 'fuel-system', 'bore', 'stroke', 'compression-ratio',
'horsepower', 'peak-rpm', 'city-mpg', 'highway-mpg', 'price'])

# displayed top rows of csv
auto.head()

# data types of columns
auto.dtypes

# number of rows and columns for the data
auto.shape

# checking values for the given column with the count for each value
print(auto['symboling'].value_counts())
# checking least and maximum values
min(auto['symboling'])
max(auto['symboling'])
# taking values in the range specified
auto['symboling'] = auto['symboling'][auto['symboling'].isin([-3, -2, -1, 0, 1, 2, 3])]
# checking all values again
print(auto['symboling'].value_counts())


print(auto['normalized-losses'].value_counts())
min(auto['normalized-losses'])
max(auto['normalized-losses'])
# considering values between 65 and 256
auto['normalized-losses'] = auto['normalized-losses'][auto['normalized-losses'].isin(range(65, 257))]
# plotting histogram to confirm skewness
print(auto['normalized-losses'] .plot(kind='hist', bins = 10))
# imputing median
auto['normalized-losses'] = auto['normalized-losses'].fillna(auto['normalized-losses'].median(axis=0))
print(auto['normalized-losses'].value_counts())

print(auto['make'].value_counts())
# removing whitespaces
auto['make']=auto['make'].str.strip()
# converting to lowercase
auto['make'] = auto['make'].str.lower()
# replacing typo by actual value
auto['make'] = auto['make'].replace('vol00112ov', 'volvo')
print(auto['make'].value_counts())


print(auto['fuel-type'].value_counts())
auto['fuel-type'] = auto['fuel-type'].str.strip()
auto['fuel-type'] = auto['fuel-type'].str.lower()
print(auto['fuel-type'].value_counts())


print(auto['aspiration'].value_counts())
auto['aspiration'] = auto['aspiration'].str.strip()
auto['aspiration'] = auto['aspiration'].str.lower()
auto['aspiration'] = auto['aspiration'].replace('turrrrbo', 'turbo')
print(auto['aspiration'].value_counts())

print(auto['num-of-doors'].value_counts())
auto['num-of-doors'] = auto['num-of-doors'].str.strip()
auto['num-of-doors'] = auto['num-of-doors'].str.lower()
auto['num-of-doors'] = auto['num-of-doors'].replace('fourr', 'four')
# dropping all null values
auto['num-of-doors'] = auto['num-of-doors'].dropna()
print(auto['num-of-doors'].value_counts())


print(auto['body-style'].value_counts())
auto['body-style'] = auto['body-style'].str.strip()
auto['body-style'] = auto['body-style'].str.lower()
print(auto['body-style'].value_counts())

print(auto['drive-wheels'].value_counts())
auto['drive-wheels'] = auto['drive-wheels'].str.strip()
auto['drive-wheels'] = auto['drive-wheels'].str.lower()
print(auto['drive-wheels'].value_counts())


print(auto['engine-location'].value_counts())
auto['engine-location'] = auto['engine-location'].str.strip()
auto['engine-location'] = auto['engine-location'].str.lower()
print(auto['engine-location'].value_counts())

print(auto['wheel-base'].value_counts())
min(auto['wheel-base'])
max(auto['wheel-base'])
print(auto['wheel-base'].value_counts())

print(auto['length'].value_counts())
min(auto['length'])
max(auto['length'])
print(auto['length'].value_counts())

print(auto['width'].value_counts())
min(auto['width'])
max(auto['width'])
print(auto['width'].value_counts())

print(auto['height'].value_counts())
min(auto['height'])
max(auto['height'])
print(auto['height'].value_counts())

print(auto['curb-weight'].value_counts())
min(auto['curb-weight'])
max(auto['curb-weight'])
print(auto['curb-weight'].value_counts())

print(auto['engine-type'].value_counts())
auto['engine-type'] = auto['engine-type'].str.strip()
auto['engine-type'] = auto['engine-type'].str.lower()
print(auto['engine-type'].value_counts())

print(auto['num-of-cylinders'].value_counts())
auto['num-of-cylinders'] = auto['num-of-cylinders'].str.strip()
auto['num-of-cylinders'] = auto['num-of-cylinders'].str.lower()
print(auto['num-of-cylinders'].value_counts())

print(auto['engine-size'].value_counts())
min(auto['engine-size'])
max(auto['engine-size'])
print(auto['engine-size'].value_counts())

print(auto['fuel-system'].value_counts())
auto['fuel-system'] = auto['fuel-system'].str.strip()
auto['fuel-system'] = auto['fuel-system'].str.lower()
print(auto['fuel-system'].value_counts())

print(auto['bore'].value_counts())
min(auto['bore'])
max(auto['bore'])
auto['bore'] = auto['bore'].dropna()
print(auto['bore'].value_counts())

print(auto['stroke'].value_counts())
min(auto['stroke'])
max(auto['stroke'])
auto['stroke'] = auto['stroke'].dropna()
print(auto['stroke'].value_counts())

print(auto['compression-ratio'].value_counts())
min(auto['compression-ratio'])
max(auto['compression-ratio'])
print(auto['compression-ratio'].value_counts())

print(auto['horsepower'].value_counts())
min(auto['horsepower'])
max(auto['horsepower'])
auto['horsepower'] = auto['horsepower'].dropna()
print(auto['horsepower'].value_counts())

print(auto['peak-rpm'].value_counts())
min(auto['peak-rpm'])
max(auto['peak-rpm'])
auto['peak-rpm'] = auto['peak-rpm'].dropna()
print(auto['peak-rpm'].value_counts())

print(auto['city-mpg'].value_counts())
min(auto['city-mpg'])
max(auto['city-mpg'])
print(auto['city-mpg'].value_counts())

print(auto['highway-mpg'].value_counts())
min(auto['highway-mpg'])
max(auto['highway-mpg'])
print(auto['highway-mpg'].value_counts())

print(auto['price'].value_counts())
min(auto['price'])
max(auto['price'])
auto['price'] = auto['price'][auto['price'].isin(range(5118, 45401))]
auto['price'] = auto['price'].dropna()
print(auto['price'].value_counts())
# Out:
#  0    67
#  1    54
# -1    52
#  2    32
#  3    27
#  4     3
# -2     3
# Name: symboling, dtype: int64
#  0.0    67
#  1.0    54
# -1.0    52
#  2.0    32
#  3.0    27
# -2.0     3
# Name: symboling, dtype: int64
# 95.0     27
# 161.0    11
# 91.0      8
# 150.0     7
# 74.0      7
# 104.0     6
# 134.0     6
# 128.0     6
# 94.0      5
# 103.0     5
# 65.0      5
# 85.0      5
# 168.0     5
# 102.0     5
# 122.0     4
# 118.0     4
# 148.0     4
# 93.0      4
# 106.0     4
# 125.0     3
# 115.0     3
# 25.0      3
# 101.0     3
# 137.0     3
# 83.0      3
# 154.0     3
# 145.0     2
# 113.0     2
# 110.0     2
# 81.0      2
# 188.0     2
# 192.0     2
# 158.0     2
# 153.0     2
# 129.0     2
# 194.0     2
# 197.0     2
# 87.0      2
# 119.0     2
# 89.0      2
# 108.0     2
# 164.0     2
# 231.0     1
# 78.0      1
# 186.0     1
# 107.0     1
# 77.0      1
# 98.0      1
# 121.0     1
# 142.0     1
# 90.0      1
# 256.0     1
# Name: normalized-losses, dtype: int64
# AxesSubplot(0.125,0.11;0.775x0.77)
# 106.0    54
# 95.0     27
# 161.0    11
# 91.0      8
# 74.0      7
# 150.0     7
# 104.0     6
# 134.0     6
# 128.0     6
# 85.0      5
# 103.0     5
# 168.0     5
# 94.0      5
# 65.0      5
# 102.0     5
# 93.0      4
# 148.0     4
# 122.0     4
# 118.0     4
# 125.0     3
# 154.0     3
# 115.0     3
# 137.0     3
# 101.0     3
# 83.0      3
# 188.0     2
# 192.0     2
# 81.0      2
# 158.0     2
# 197.0     2
# 164.0     2
# 110.0     2
# 145.0     2
# 113.0     2
# 153.0     2
# 129.0     2
# 87.0      2
# 89.0      2
# 108.0     2
# 194.0     2
# 119.0     2
# 107.0     1
# 78.0      1
# 77.0      1
# 142.0     1
# 90.0      1
# 256.0     1
# 98.0      1
# 121.0     1
# 231.0     1
# 186.0     1
# Name: normalized-losses, dtype: int64
# toyota           32
# volvo            29
# mazda            17
# nissan           17
# honda            13
# mitsubishi       13
# volkswagen       12
# subaru           12
# peugot           10
# volvo             9
# dodge             9
# mercedes-benz     8
# bmw               8
# audi              7
# plymouth          7
# saab              6
# porsche           5
# isuzu             4
# alfa-romero       3
# chevrolet         3
# vol00112ov        3
#  volvo            3
# jaguar            3
# renault           2
# Peugot            1
# Nissan            1
# mercury           1
# Name: make, dtype: int64
# volvo            44
# toyota           32
# nissan           18
# mazda            17
# mitsubishi       13
# honda            13
# subaru           12
# volkswagen       12
# peugot           11
# dodge             9
# bmw               8
# mercedes-benz     8
# plymouth          7
# audi              7
# saab              6
# porsche           5
# isuzu             4
# chevrolet         3
# alfa-romero       3
# jaguar            3
# renault           2
# mercury           1
# Name: make, dtype: int64
# gas       207
# diesel     27
# Gas         2
# Diesel      1
# gas         1
# Name: fuel-type, dtype: int64
# gas       210
# diesel     28
# Name: fuel-type, dtype: int64
# std         175
# turbo        57
# turrrrbo      3
# Std           2
# std           1
# Name: aspiration, dtype: int64
# std      178
# turbo     60
# Name: aspiration, dtype: int64
# four     142
# two       89
# fourR      3
# Four       1
# four       1
# Name: num-of-doors, dtype: int64
# four    147
# two      89
# Name: num-of-doors, dtype: int64
# sedan          124
# hatchback       70
# wagon           26
# hardtop          8
# convertible      6
# sedan            2
# Sedan            1
# Wagon            1
# Name: body-style, dtype: int64
# sedan          127
# hatchback       70
# wagon           27
# hardtop          8
# convertible      6
# Name: body-style, dtype: int64
# fwd     118
# rwd     108
# 4wd       9
# rwd       1
# fwd       1
# Fwd       1
# Name: drive-wheels, dtype: int64
# fwd    120
# rwd    109
# 4wd      9
# Name: drive-wheels, dtype: int64
# front     232
# Front       1
# REAR        1
# rear        1
# front       1
# FRONT       1
# Rear        1
# Name: engine-location, dtype: int64
# front    235
# rear       3
# Name: engine-location, dtype: int64
# 109.1    36
# 94.5     21
# 93.7     20
# 95.7     13
# 96.5      8
# 104.3     8
# 98.4      7
# 97.3      7
# 98.8      6
# 107.9     6
# 99.1      6
# 96.3      6
# 100.4     6
# 93.1      5
# 102.4     5
# 97.2      5
# 95.9      5
# 101.2     4
# 114.2     4
# 95.3      4
# 97.0      4
# 105.8     3
# 89.5      3
# 110.0     3
# 103.5     3
# 115.6     2
# 104.5     2
# 113.0     2
# 96.9      2
# 88.6      2
# 86.6      2
# 96.1      2
# 102.9     2
# 104.9     2
# 99.8      2
# 103.3     2
# 91.3      2
# 96.6      1
# 102.0     1
# 99.5      1
# 120.9     1
# 94.3      1
# 99.2      1
# 96.0      1
# 108.0     1
# 112.0     1
# 93.0      1
# 95.1      1
# 88.4      1
# 102.7     1
# 93.3      1
# 99.4      1
# 106.7     1
# Name: wheel-base, dtype: int64
# 109.1    36
# 94.5     21
# 93.7     20
# 95.7     13
# 96.5      8
# 104.3     8
# 98.4      7
# 97.3      7
# 98.8      6
# 107.9     6
# 99.1      6
# 96.3      6
# 100.4     6
# 93.1      5
# 102.4     5
# 97.2      5
# 95.9      5
# 101.2     4
# 114.2     4
# 95.3      4
# 97.0      4
# 105.8     3
# 89.5      3
# 110.0     3
# 103.5     3
# 115.6     2
# 104.5     2
# 113.0     2
# 96.9      2
# 88.6      2
# 86.6      2
# 96.1      2
# 102.9     2
# 104.9     2
# 99.8      2
# 103.3     2
# 91.3      2
# 96.6      1
# 102.0     1
# 99.5      1
# 120.9     1
# 94.3      1
# 99.2      1
# 96.0      1
# 108.0     1
# 112.0     1
# 93.0      1
# 95.1      1
# 88.4      1
# 102.7     1
# 93.3      1
# 99.4      1
# 106.7     1
# Name: wheel-base, dtype: int64
# 188.8    44
# 157.3    15
# 166.3     7
# 171.7     7
# 186.7     7
# 165.3     6
# 177.8     6
# 176.2     6
# 186.6     6
# 176.8     5
# 172.0     5
# 175.6     5
# 173.2     5
# 172.4     4
# 169.0     4
# 168.7     4
# 198.9     4
# 168.9     4
# 192.7     3
# 158.7     3
# 155.9     3
# 170.7     3
# 169.7     3
# 159.1     3
# 150.0     3
# 175.4     3
# 168.8     2
# 167.3     2
# 170.2     2
# 173.4     2
#          ..
# 173.6     2
# 166.8     2
# 187.5     1
# 165.6     1
# 178.5     1
# 172.6     1
# 178.4     1
# 181.5     1
# 208.1     1
# 159.3     1
# 197.0     1
# 162.4     1
# 165.7     1
# 158.8     1
# 180.3     1
# 169.1     1
# 157.1     1
# 156.9     1
# 171.2     1
# 163.4     1
# 178.2     1
# 191.7     1
# 199.2     1
# 141.1     1
# 181.7     1
# 157.9     1
# 177.3     1
# 175.7     1
# 193.8     1
# 183.1     1
# Name: length, Length: 75, dtype: int64
# 188.8    44
# 157.3    15
# 166.3     7
# 171.7     7
# 186.7     7
# 165.3     6
# 177.8     6
# 176.2     6
# 186.6     6
# 176.8     5
# 172.0     5
# 175.6     5
# 173.2     5
# 172.4     4
# 169.0     4
# 168.7     4
# 198.9     4
# 168.9     4
# 192.7     3
# 158.7     3
# 155.9     3
# 170.7     3
# 169.7     3
# 159.1     3
# 150.0     3
# 175.4     3
# 168.8     2
# 167.3     2
# 170.2     2
# 173.4     2
#          ..
# 173.6     2
# 166.8     2
# 187.5     1
# 165.6     1
# 178.5     1
# 172.6     1
# 178.4     1
# 181.5     1
# 208.1     1
# 159.3     1
# 197.0     1
# 162.4     1
# 165.7     1
# 158.8     1
# 180.3     1
# 169.1     1
# 157.1     1
# 156.9     1
# 171.2     1
# 163.4     1
# 178.2     1
# 191.7     1
# 199.2     1
# 141.1     1
# 181.7     1
# 157.9     1
# 177.3     1
# 175.7     1
# 193.8     1
# 183.1     1
# Name: length, Length: 75, dtype: int64
# 68.9    30
# 63.8    24
# 66.5    23
# 65.4    15
# 63.6    11
# 64.4    10
# 68.4    10
# 64.0     9
# 65.5     8
# 67.2     8
# 65.2     7
# 68.8     6
# 65.6     6
# 66.3     6
# 64.2     6
# 66.9     5
# 67.9     5
# 65.7     4
# 64.8     4
# 63.9     3
# 70.3     3
# 71.4     3
# 65.0     3
# 71.7     3
# 64.6     2
# 64.1     2
# 67.7     2
# 66.1     2
# 68.3     2
# 69.6     2
# 61.8     1
# 72.0     1
# 63.4     1
# 62.5     1
# 66.0     1
# 72.3     1
# 70.5     1
# 70.9     1
# 68.0     1
# 66.2     1
# 70.6     1
# 66.4     1
# 60.3     1
# 66.6     1
# Name: width, dtype: int64
# 68.9    30
# 63.8    24
# 66.5    23
# 65.4    15
# 63.6    11
# 64.4    10
# 68.4    10
# 64.0     9
# 65.5     8
# 67.2     8
# 65.2     7
# 68.8     6
# 65.6     6
# 66.3     6
# 64.2     6
# 66.9     5
# 67.9     5
# 65.7     4
# 64.8     4
# 63.9     3
# 70.3     3
# 71.4     3
# 65.0     3
# 71.7     3
# 64.6     2
# 64.1     2
# 67.7     2
# 66.1     2
# 68.3     2
# 69.6     2
# 61.8     1
# 72.0     1
# 63.4     1
# 62.5     1
# 66.0     1
# 72.3     1
# 70.5     1
# 70.9     1
# 68.0     1
# 66.2     1
# 70.6     1
# 66.4     1
# 60.3     1
# 66.6     1
# Name: width, dtype: int64
# 55.5    40
# 50.8    14
# 52.0    12
# 55.7    12
# 54.5    10
# 54.1    10
# 56.7     8
# 54.3     8
# 52.6     7
# 56.1     7
# 51.6     7
# 53.0     6
# 54.9     6
# 50.2     6
# 52.8     6
# 57.5     5
# 53.7     5
# 55.1     5
# 50.6     5
# 53.3     4
# 49.6     4
# 58.7     4
# 53.5     3
# 49.7     3
# 59.1     3
# 56.2     3
# 52.5     3
# 54.4     2
# 49.4     2
# 48.8     2
# 56.3     2
# 51.4     2
# 59.8     2
# 56.5     2
# 54.7     2
# 53.9     2
# 50.5     2
# 56.0     1
# 51.0     1
# 52.4     1
# 55.4     1
# 55.6     1
# 53.2     1
# 58.3     1
# 55.9     1
# 47.8     1
# 54.8     1
# 53.1     1
# 55.2     1
# Name: height, dtype: int64
# 55.5    40
# 50.8    14
# 52.0    12
# 55.7    12
# 54.5    10
# 54.1    10
# 56.7     8
# 54.3     8
# 52.6     7
# 56.1     7
# 51.6     7
# 53.0     6
# 54.9     6
# 50.2     6
# 52.8     6
# 57.5     5
# 53.7     5
# 55.1     5
# 50.6     5
# 53.3     4
# 49.6     4
# 58.7     4
# 53.5     3
# 49.7     3
# 59.1     3
# 56.2     3
# 52.5     3
# 54.4     2
# 49.4     2
# 48.8     2
# 56.3     2
# 51.4     2
# 59.8     2
# 56.5     2
# 54.7     2
# 53.9     2
# 50.5     2
# 56.0     1
# 51.0     1
# 52.4     1
# 55.4     1
# 55.6     1
# 53.2     1
# 58.3     1
# 55.9     1
# 47.8     1
# 54.8     1
# 53.1     1
# 55.2     1
# Name: height, dtype: int64
# 3062    9
# 3217    9
# 3012    6
# 3049    6
# 2952    6
# 2385    4
# 2275    3
# 1918    3
# 3157    3
# 1989    3
# 2337    2
# 2403    2
# 2414    2
# 2145    2
# 3230    2
# 1876    2
# 2395    2
# 1874    2
# 3139    2
# 2128    2
# 2756    2
# 3252    2
# 2380    2
# 2410    2
# 1967    2
# 2191    2
# 3075    2
# 2579    2
# 2290    2
# 2024    2
#        ..
# 1938    1
# 2190    1
# 2094    1
# 2302    1
# 2443    1
# 2954    1
# 2261    1
# 2695    1
# 3034    1
# 3715    1
# 1945    1
# 3740    1
# 2563    1
# 3485    1
# 1971    1
# 1985    1
# 3505    1
# 2480    1
# 2734    1
# 2221    1
# 2670    1
# 2926    1
# 1950    1
# 3750    1
# 1956    1
# 2037    1
# 2465    1
# 2976    1
# 1951    1
# 2304    1
# Name: curb-weight, Length: 171, dtype: int64
# 3062    9
# 3217    9
# 3012    6
# 3049    6
# 2952    6
# 2385    4
# 2275    3
# 1918    3
# 3157    3
# 1989    3
# 2337    2
# 2403    2
# 2414    2
# 2145    2
# 3230    2
# 1876    2
# 2395    2
# 1874    2
# 3139    2
# 2128    2
# 2756    2
# 3252    2
# 2380    2
# 2410    2
# 1967    2
# 2191    2
# 3075    2
# 2579    2
# 2290    2
# 2024    2
#        ..
# 1938    1
# 2190    1
# 2094    1
# 2302    1
# 2443    1
# 2954    1
# 2261    1
# 2695    1
# 3034    1
# 3715    1
# 1945    1
# 3740    1
# 2563    1
# 3485    1
# 1971    1
# 1985    1
# 3505    1
# 2480    1
# 2734    1
# 2221    1
# 2670    1
# 2926    1
# 1950    1
# 3750    1
# 1956    1
# 2037    1
# 2465    1
# 2976    1
# 1951    1
# 2304    1
# Name: curb-weight, Length: 171, dtype: int64
# ohc      175
# ohcv      18
# ohcf      15
# l         12
# dohc      12
# rotor      4
# Ohc        1
# dohcv      1
# Name: engine-type, dtype: int64
# ohc      176
# ohcv      18
# ohcf      15
# l         12
# dohc      12
# rotor      4
# dohcv      1
# Name: engine-type, dtype: int64
# four      175
# six        37
# five       10
# eight       5
# two         4
# Four        2
#  four       2
# five        1
# three       1
# twelve      1
# Name: num-of-cylinders, dtype: int64
# four      179
# six        37
# five       11
# eight       5
# two         4
# three       1
# twelve      1
# Name: num-of-cylinders, dtype: int64
# 141    25
# 122    15
# 92     15
# 98     14
# 97     14
# 108    13
# 110    12
# 90     12
# 145     9
# 109     8
# 120     7
# 121     6
# 130     6
# 146     6
# 152     6
# 173     6
# 181     6
# 156     5
# 91      5
# 136     5
# 183     4
# 164     3
# 171     3
# 209     3
# 194     3
# 70      3
# 234     2
# 258     2
# 131     2
# 132     2
# 134     2
# 140     2
# 79      1
# 304     1
# 308     1
# 61      1
# 326     1
# 111     1
# 80      1
# 203     1
# 119     1
# 151     1
# 103     1
# 161     1
# Name: engine-size, dtype: int64
# 141    25
# 122    15
# 92     15
# 98     14
# 97     14
# 108    13
# 110    12
# 90     12
# 145     9
# 109     8
# 120     7
# 121     6
# 130     6
# 146     6
# 152     6
# 173     6
# 181     6
# 156     5
# 91      5
# 136     5
# 183     4
# 164     3
# 171     3
# 209     3
# 194     3
# 70      3
# 234     2
# 258     2
# 131     2
# 132     2
# 134     2
# 140     2
# 79      1
# 304     1
# 308     1
# 61      1
# 326     1
# 111     1
# 80      1
# 203     1
# 119     1
# 151     1
# 103     1
# 161     1
# Name: engine-size, dtype: int64
# mpfi     116
# 2bbl      66
# idi       28
# 1bbl      11
# spdi       9
# 4bbl       3
# mpfi       2
# spfi       1
# Mpfi       1
# mfi        1
# Name: fuel-system, dtype: int64
# mpfi    119
# 2bbl     66
# idi      28
# 1bbl     11
# spdi      9
# 4bbl      3
# spfi      1
# mfi       1
# Name: fuel-system, dtype: int64
# 3.78    26
# 3.62    25
# 3.19    20
# 3.15    15
# 3.01    13
# 2.97    12
# 3.03    12
# 3.58    11
# 3.46     9
# 3.43     8
# 3.31     8
# 2.91     7
# 3.27     7
# 3.54     6
# 3.39     6
# 3.05     6
# 3.70     5
# 3.35     4
# 3.17     3
# 3.74     3
# 3.59     3
# 3.13     2
# 3.24     2
# 3.63     2
# 3.80     2
# 3.94     2
# 3.47     2
# 3.33     2
# 3.50     2
# 2.92     1
# 3.61     1
# 3.08     1
# 2.99     1
# 3.76     1
# 2.68     1
# 3.34     1
# 3.60     1
# 2.54     1
# Name: bore, dtype: int64
# 3.78    26
# 3.62    25
# 3.19    20
# 3.15    15
# 3.01    13
# 2.97    12
# 3.03    12
# 3.58    11
# 3.46     9
# 3.43     8
# 3.31     8
# 2.91     7
# 3.27     7
# 3.54     6
# 3.39     6
# 3.05     6
# 3.70     5
# 3.35     4
# 3.17     3
# 3.74     3
# 3.59     3
# 3.13     2
# 3.24     2
# 3.63     2
# 3.80     2
# 3.94     2
# 3.47     2
# 3.33     2
# 3.50     2
# 2.92     1
# 3.61     1
# 3.08     1
# 2.99     1
# 3.76     1
# 2.68     1
# 3.34     1
# 3.60     1
# 2.54     1
# Name: bore, dtype: int64
# 3.15    34
# 3.40    28
# 3.03    14
# 3.23    14
# 3.39    13
# 2.64    11
# 3.35     9
# 3.29     9
# 3.46     8
# 3.27     6
# 3.19     6
# 2.87     6
# 3.07     6
# 3.11     6
# 3.58     6
# 3.50     6
# 3.41     6
# 3.64     5
# 3.52     5
# 3.86     4
# 3.47     4
# 3.54     4
# 2.90     3
# 3.90     3
# 3.10     2
# 3.08     2
# 2.80     2
# 2.68     2
# 2.19     2
# 4.17     2
# 3.16     1
# 2.76     1
# 2.07     1
# 3.12     1
# 3.21     1
# 2.36     1
# Name: stroke, dtype: int64
# 3.15    34
# 3.40    28
# 3.03    14
# 3.23    14
# 3.39    13
# 2.64    11
# 3.35     9
# 3.29     9
# 3.46     8
# 3.27     6
# 3.19     6
# 2.87     6
# 3.07     6
# 3.11     6
# 3.58     6
# 3.50     6
# 3.41     6
# 3.64     5
# 3.52     5
# 3.86     4
# 3.47     4
# 3.54     4
# 2.90     3
# 3.90     3
# 3.10     2
# 3.08     2
# 2.80     2
# 2.68     2
# 2.19     2
# 4.17     2
# 3.16     1
# 2.76     1
# 2.07     1
# 3.12     1
# 3.21     1
# 2.36     1
# Name: stroke, dtype: int64
# 9.00     46
# 9.40     26
# 9.50     26
# 8.50     14
# 8.70     14
# 23.00    13
# 9.30     11
# 8.00      8
# 8.80      8
# 9.20      8
# 7.00      7
# 7.50      7
# 9.60      5
# 8.40      5
# 21.00     5
# 8.60      5
# 21.50     4
# 7.60      4
# 10.00     3
# 22.50     3
# 8.30      3
# 7.70      2
# 8.10      2
# 9.31      1
# 21.90     1
# 22.00     1
# 11.50     1
# 9.41      1
# 10.10     1
# 9.10      1
# 22.70     1
# 7.80      1
# Name: compression-ratio, dtype: int64
# 9.00     46
# 9.40     26
# 9.50     26
# 8.50     14
# 8.70     14
# 23.00    13
# 9.30     11
# 8.00      8
# 8.80      8
# 9.20      8
# 7.00      7
# 7.50      7
# 9.60      5
# 8.40      5
# 21.00     5
# 8.60      5
# 21.50     4
# 7.60      4
# 10.00     3
# 22.50     3
# 8.30      3
# 7.70      2
# 8.10      2
# 9.31      1
# 21.90     1
# 22.00     1
# 11.50     1
# 9.41      1
# 10.10     1
# 9.10      1
# 22.70     1
# 7.80      1
# Name: compression-ratio, dtype: int64
# 68.0     19
# 114.0    19
# 160.0    11
# 70.0     11
# 69.0     10
# 106.0     9
# 116.0     9
# 110.0     8
# 95.0      7
# 88.0      6
# 62.0      6
# 134.0     6
# 101.0     6
# 97.0      5
# 76.0      5
# 82.0      5
# 84.0      5
# 102.0     5
# 145.0     5
# 86.0      4
# 123.0     4
# 111.0     4
# 162.0     4
# 92.0      4
# 207.0     3
# 85.0      3
# 121.0     3
# 182.0     3
# 90.0      3
# 152.0     3
# 73.0      3
# 100.0     2
# 52.0      2
# 156.0     2
# 161.0     2
# 184.0     2
# 112.0     2
# 94.0      2
# 56.0      2
# 155.0     2
# 176.0     2
# 78.0      1
# 143.0     1
# 154.0     1
# 55.0      1
# 115.0     1
# 142.0     1
# 140.0     1
# 64.0      1
# 288.0     1
# 175.0     1
# 200.0     1
# 48.0      1
# 135.0     1
# 262.0     1
# 120.0     1
# 58.0      1
# 60.0      1
# 72.0      1
# Name: horsepower, dtype: int64
# 68.0     19
# 114.0    19
# 160.0    11
# 70.0     11
# 69.0     10
# 106.0     9
# 116.0     9
# 110.0     8
# 95.0      7
# 88.0      6
# 62.0      6
# 134.0     6
# 101.0     6
# 97.0      5
# 76.0      5
# 82.0      5
# 84.0      5
# 102.0     5
# 145.0     5
# 86.0      4
# 123.0     4
# 111.0     4
# 162.0     4
# 92.0      4
# 207.0     3
# 85.0      3
# 121.0     3
# 182.0     3
# 90.0      3
# 152.0     3
# 73.0      3
# 100.0     2
# 52.0      2
# 156.0     2
# 161.0     2
# 184.0     2
# 112.0     2
# 94.0      2
# 56.0      2
# 155.0     2
# 176.0     2
# 78.0      1
# 143.0     1
# 154.0     1
# 55.0      1
# 115.0     1
# 142.0     1
# 140.0     1
# 64.0      1
# 288.0     1
# 175.0     1
# 200.0     1
# 48.0      1
# 135.0     1
# 262.0     1
# 120.0     1
# 58.0      1
# 60.0      1
# 72.0      1
# Name: horsepower, dtype: int64
# 4800.0    44
# 5500.0    42
# 5000.0    27
# 5400.0    26
# 5200.0    23
# 6000.0     9
# 4500.0     7
# 5800.0     7
# 5250.0     7
# 5300.0     6
# 4200.0     5
# 5100.0     5
# 4150.0     5
# 4750.0     4
# 4350.0     4
# 4400.0     3
# 4250.0     3
# 5900.0     3
# 6600.0     2
# 5750.0     1
# 4650.0     1
# 5600.0     1
# 4900.0     1
# Name: peak-rpm, dtype: int64
# 4800.0    44
# 5500.0    42
# 5000.0    27
# 5400.0    26
# 5200.0    23
# 6000.0     9
# 4500.0     7
# 5800.0     7
# 5250.0     7
# 5300.0     6
# 4200.0     5
# 5100.0     5
# 4150.0     5
# 4750.0     4
# 4350.0     4
# 4400.0     3
# 4250.0     3
# 5900.0     3
# 6600.0     2
# 5750.0     1
# 4650.0     1
# 5600.0     1
# 4900.0     1
# Name: peak-rpm, dtype: int64
# 19    40
# 31    28
# 24    22
# 26    20
# 23    17
# 17    15
# 27    14
# 18     8
# 21     8
# 30     8
# 25     8
# 28     7
# 38     7
# 16     6
# 37     6
# 22     4
# 15     3
# 29     3
# 20     3
# 14     2
# 49     1
# 47     1
# 32     1
# 33     1
# 34     1
# 35     1
# 36     1
# 45     1
# 13     1
# Name: city-mpg, dtype: int64
# 19    40
# 31    28
# 24    22
# 26    20
# 23    17
# 17    15
# 27    14
# 18     8
# 21     8
# 30     8
# 25     8
# 28     7
# 38     7
# 16     6
# 37     6
# 22     4
# 15     3
# 29     3
# 20     3
# 14     2
# 49     1
# 47     1
# 32     1
# 33     1
# 34     1
# 35     1
# 36     1
# 45     1
# 13     1
# Name: city-mpg, dtype: int64
# 25    32
# 28    18
# 24    17
# 38    17
# 30    16
# 32    16
# 34    14
# 37    13
# 27    13
# 23    12
# 29    10
# 22    10
# 33     9
# 31     8
# 43     4
# 41     3
# 42     3
# 26     3
# 20     2
# 19     2
# 18     2
# 16     2
# 36     2
# 39     2
# 46     2
# 47     2
# 53     1
# 50     1
# 17     1
# 54     1
# Name: highway-mpg, dtype: int64
# 25    32
# 28    18
# 24    17
# 38    17
# 30    16
# 32    16
# 34    14
# 37    13
# 27    13
# 23    12
# 29    10
# 22    10
# 33     9
# 31     8
# 43     4
# 41     3
# 42     3
# 26     3
# 20     2
# 19     2
# 18     2
# 16     2
# 36     2
# 39     2
# 46     2
# 47     2
# 53     1
# 50     1
# 17     1
# 54     1
# Name: highway-mpg, dtype: int64
# 21485.0    6
# 22625.0    6
# 0.0        6
# 19045.0    6
# 16845.0    6
# 22470.0    6
# 18950.0    3
# 7957.0     2
# 5572.0     2
# 6229.0     2
# 7898.0     2
# 8495.0     2
# 13499.0    2
# 8845.0     2
# 6692.0     2
# 7609.0     2
# 16500.0    2
# 18150.0    2
# 8921.0     2
# 9279.0     2
# 7775.0     2
# 7295.0     2
# 7689.0     1
# 7975.0     1
# 6575.0     1
# 10898.0    1
# 22018.0    1
# 5389.0     1
# 13415.0    1
# 9980.0     1
#           ..
# 11248.0    1
# 18344.0    1
# 6488.0     1
# 13200.0    1
# 8358.0     1
# 10198.0    1
# 11245.0    1
# 7895.0     1
# 8249.0     1
# 18420.0    1
# 7053.0     1
# 16503.0    1
# 9989.0     1
# 12170.0    1
# 6855.0     1
# 6785.0     1
# 14399.0    1
# 7395.0     1
# 11199.0    1
# 12940.0    1
# 17199.0    1
# 7099.0     1
# 6338.0     1
# 9295.0     1
# 15580.0    1
# 6377.0     1
# 30760.0    1
# 16925.0    1
# 15998.0    1
# 18920.0    1
# Name: price, Length: 187, dtype: int64
# 19045.0    6
# 21485.0    6
# 16845.0    6
# 22625.0    6
# 22470.0    6
# 18950.0    3
# 5572.0     2
# 13499.0    2
# 7898.0     2
# 7609.0     2
# 7295.0     2
# 6229.0     2
# 8495.0     2
# 8845.0     2
# 18150.0    2
# 6692.0     2
# 9279.0     2
# 16500.0    2
# 8921.0     2
# 7957.0     2
# 7775.0     2
# 5389.0     1
# 22018.0    1
# 9549.0     1
# 13415.0    1
# 9980.0     1
# 6575.0     1
# 7975.0     1
# 7499.0     1
# 7689.0     1
#           ..
# 11248.0    1
# 18344.0    1
# 6488.0     1
# 13200.0    1
# 8358.0     1
# 10198.0    1
# 11245.0    1
# 7895.0     1
# 8249.0     1
# 18420.0    1
# 7053.0     1
# 16503.0    1
# 9989.0     1
# 12170.0    1
# 6855.0     1
# 6785.0     1
# 14399.0    1
# 7395.0     1
# 11199.0    1
# 12940.0    1
# 17199.0    1
# 7099.0     1
# 6338.0     1
# 9295.0     1
# 15580.0    1
# 6377.0     1
# 30760.0    1
# 16925.0    1
# 15998.0    1
# 18920.0    1
# Name: price, Length: 186, dtype: int64

# %%
# Task 2: Data Exploration
# 1. Choose 1 column with nominal values, 1 column with ordinal Values, and 1 column with numerical values


#Code goes after this line

# matplotlib.pyplot imported
import matplotlib.pyplot as plt
# fuel-type pie chart
auto['fuel-type'].value_counts().plot(kind='pie',autopct='%.2f',figsize = (6,6), title='Pie Chart for fuel-type')

# num-of-cylinders pie chart
auto['num-of-cylinders'].value_counts().plot(kind='pie',autopct='%.2f',figsize = (10,10), title='Pie Chart for num-of-cylinders')

# price histogram
auto['price'].plot(kind='hist', bins = 10,figsize = (6,6),title='Histogram for price')
plt.xlabel("price (USD)")
# Out:
# Text(0.5,0,'price (USD)')

# %%
# Task 2: Data Exploration
# 2. Explore the relationships between columns; at least 3 visualisations with plausible hypothesis

#Code goes after this line

# boxplot for price and fuel-type
auto.boxplot(column='price', by='fuel-type', figsize = (6,6))
plt.xlabel("fuel-type")
plt.ylabel("price (USD)")

# boxplot for price and number of cylinders
auto.boxplot(column='price', by='num-of-cylinders', figsize = (6,6))
plt.xlabel("num-of-cylinders")
plt.ylabel("price (USD)")

# scatter plot for engine size vs price
auto.plot(kind= 'scatter', x=16, y=25, figsize = (6,6))
plt.title("Scatter plot of Engine size vs Price")
plt.ylabel("price (USD)")
# Out:
# Text(0,0.5,'price (USD)')

# %%
# Task 2: Data Exploration
# 3. Scatter matrix for all numerical columns

#Code goes after this line


from pandas.tools.plotting import scatter_matrix
# scatter matrix for all numerical values
print(scatter_matrix(auto, alpha=0.2, figsize=(50,50), diagonal='hist'))
plt.suptitle("Scatter matrix for all numerical values")
# Out:
# C:\Users\ria93\Anaconda2\lib\site-packages\ipykernel_launcher.py:9: FutureWarning: 'pandas.tools.plotting.scatter_matrix' is deprecated, import 'pandas.plotting.scatter_matrix' instead.
#   if __name__ == '__main__':
# [[<matplotlib.axes._subplots.AxesSubplot object at 0x000000000A59F2E8>
#   <matplotlib.axes._subplots.AxesSubplot object at 0x000000000B4C5D68>
#   <matplotlib.axes._subplots.AxesSubplot object at 0x000000000B50C518>
#   <matplotlib.axes._subplots.AxesSubplot object at 0x000000000B560C50>
#   <matplotlib.axes._subplots.AxesSubplot object at 0x000000000B665400>
#   <matplotlib.axes._subplots.AxesSubplot object at 0x000000000B6DCB70>
#   <matplotlib.axes._subplots.AxesSubplot object at 0x000000000B75E320>
#   <matplotlib.axes._subplots.AxesSubplot object at 0x000000000B7D5A90>
#   <matplotlib.axes._subplots.AxesSubplot object at 0x000000000B89A240>
#   <matplotlib.axes._subplots.AxesSubplot object at 0x000000000B8CD9B0>
#   <matplotlib.axes._subplots.AxesSubplot object at 0x000000000B94F160>
#   <matplotlib.axes._subplots.AxesSubplot object at 0x000000000B9C78D0>
#   <matplotlib.axes._subplots.AxesSubplot object at 0x000000000BA4A080>
#   <matplotlib.axes._subplots.AxesSubplot object at 0x000000000BAC07F0>
#   <matplotlib.axes._subplots.AxesSubplot object at 0x000000000BB78F60>
#   <matplotlib.axes._subplots.AxesSubplot object at 0x000000000BBFE710>]
#  [<matplotlib.axes._subplots.AxesSubplot object at 0x000000000BC72E80>
#   <matplotlib.axes._subplots.AxesSubplot object at 0x000000000BD49630>
#   <matplotlib.axes._subplots.AxesSubplot object at 0x000000000BD7FDA0>
#   <matplotlib.axes._subplots.AxesSubplot object at 0x000000000BE46550>
#   <matplotlib.axes._subplots.AxesSubplot object at 0x000000000BE77CC0>
#   <matplotlib.axes._subplots.AxesSubplot object at 0x000000000BF3B470>
#   <matplotlib.axes._subplots.AxesSubplot object at 0x000000000BF71BE0>
#   <matplotlib.axes._subplots.AxesSubplot object at 0x000000000C047390>
#   <matplotlib.axes._subplots.AxesSubplot object at 0x000000000C100B00>
#   <matplotlib.axes._subplots.AxesSubplot object at 0x000000000C1A82B0>
#   <matplotlib.axes._subplots.AxesSubplot object at 0x000000000C21EA20>
#   <matplotlib.axes._subplots.AxesSubplot object at 0x000000000C2E51D0>
#   <matplotlib.axes._subplots.AxesSubplot object at 0x000000000C35A940>
#   <matplotlib.axes._subplots.AxesSubplot object at 0x000000000C3E00F0>
#   <matplotlib.axes._subplots.AxesSubplot object at 0x000000000C498860>
#   <matplotlib.axes._subplots.AxesSubplot object at 0x000000000C4C8FD0>]
#  [<matplotlib.axes._subplots.AxesSubplot object at 0x000000000C50C780>
#   <matplotlib.axes._subplots.AxesSubplot object at 0x000000000C5C5EF0>
#   <matplotlib.axes._subplots.AxesSubplot object at 0x000000000C6496A0>
#   <matplotlib.axes._subplots.AxesSubplot object at 0x000000000C6D0E10>
#   <matplotlib.axes._subplots.AxesSubplot object at 0x000000000C7975C0>
#   <matplotlib.axes._subplots.AxesSubplot object at 0x000000000C7CCD30>
#   <matplotlib.axes._subplots.AxesSubplot object at 0x000000000C8914E0>
#   <matplotlib.axes._subplots.AxesSubplot object at 0x000000000C949C50>
#   <matplotlib.axes._subplots.AxesSubplot object at 0x000000000C98A400>
#   <matplotlib.axes._subplots.AxesSubplot object at 0x000000000CA42B70>
#   <matplotlib.axes._subplots.AxesSubplot object at 0x000000000CAD9320>
#   <matplotlib.axes._subplots.AxesSubplot object at 0x000000000CB51A90>
#   <matplotlib.axes._subplots.AxesSubplot object at 0x000000000CC17240>
#   <matplotlib.axes._subplots.AxesSubplot object at 0x000000000CC4A9B0>
#   <matplotlib.axes._subplots.AxesSubplot object at 0x000000000CD10160>
#   <matplotlib.axes._subplots.AxesSubplot object at 0x000000000CD858D0>]
#  [<matplotlib.axes._subplots.AxesSubplot object at 0x000000000AC87048>
#   <matplotlib.axes._subplots.AxesSubplot object at 0x000000000AC645C0>
#   <matplotlib.axes._subplots.AxesSubplot object at 0x000000000A934668>
#   <matplotlib.axes._subplots.AxesSubplot object at 0x000000000A36E198>
#   <matplotlib.axes._subplots.AxesSubplot object at 0x000000000A2FB198>
#   <matplotlib.axes._subplots.AxesSubplot object at 0x000000000A8A7BE0>
#   <matplotlib.axes._subplots.AxesSubplot object at 0x000000000A924390>
#   <matplotlib.axes._subplots.AxesSubplot object at 0x000000000A7A0B00>
#   <matplotlib.axes._subplots.AxesSubplot object at 0x000000000AA462B0>
#   <matplotlib.axes._subplots.AxesSubplot object at 0x000000000A9A2A20>
#   <matplotlib.axes._subplots.AxesSubplot object at 0x000000000AA011D0>
#   <matplotlib.axes._subplots.AxesSubplot object at 0x000000000A975940>
#   <matplotlib.axes._subplots.AxesSubplot object at 0x000000000B4790F0>
#   <matplotlib.axes._subplots.AxesSubplot object at 0x000000000CDF1860>
#   <matplotlib.axes._subplots.AxesSubplot object at 0x000000000CEAAFD0>
#   <matplotlib.axes._subplots.AxesSubplot object at 0x000000000CEEC780>]
#  [<matplotlib.axes._subplots.AxesSubplot object at 0x000000000CF1FEF0>
#   <matplotlib.axes._subplots.AxesSubplot object at 0x000000000D0696A0>
#   <matplotlib.axes._subplots.AxesSubplot object at 0x000000000D09EE10>
#   <matplotlib.axes._subplots.AxesSubplot object at 0x000000000D0DD5C0>
#   <matplotlib.axes._subplots.AxesSubplot object at 0x000000000D1BFD30>
#   <matplotlib.axes._subplots.AxesSubplot object at 0x000000000D2434E0>
#   <matplotlib.axes._subplots.AxesSubplot object at 0x000000000D2FBC50>
#   <matplotlib.axes._subplots.AxesSubplot object at 0x000000000D3C1400>
#   <matplotlib.axes._subplots.AxesSubplot object at 0x000000000D437B70>
#   <matplotlib.axes._subplots.AxesSubplot object at 0x000000000D4B9320>
#   <matplotlib.axes._subplots.AxesSubplot object at 0x000000000D531A90>
#   <matplotlib.axes._subplots.AxesSubplot object at 0x000000000D5F6240>
#   <matplotlib.axes._subplots.AxesSubplot object at 0x000000000D66C9B0>
#   <matplotlib.axes._subplots.AxesSubplot object at 0x000000000D6F0160>
#   <matplotlib.axes._subplots.AxesSubplot object at 0x000000000D7268D0>
#   <matplotlib.axes._subplots.AxesSubplot object at 0x000000000D7A7080>]
#  [<matplotlib.axes._subplots.AxesSubplot object at 0x000000000D81E7F0>
#   <matplotlib.axes._subplots.AxesSubplot object at 0x000000000D8E8F60>
#   <matplotlib.axes._subplots.AxesSubplot object at 0x000000000D96C710>
#   <matplotlib.axes._subplots.AxesSubplot object at 0x000000000D9E4E80>
#   <matplotlib.axes._subplots.AxesSubplot object at 0x000000000DAAA630>
#   <matplotlib.axes._subplots.AxesSubplot object at 0x000000000DADFDA0>
#   <matplotlib.axes._subplots.AxesSubplot object at 0x000000000DBA3550>
#   <matplotlib.axes._subplots.AxesSubplot object at 0x000000000DC2DCC0>
#   <matplotlib.axes._subplots.AxesSubplot object at 0x000000000DCB9470>
#   <matplotlib.axes._subplots.AxesSubplot object at 0x000000000DCEBBE0>
#   <matplotlib.axes._subplots.AxesSubplot object at 0x000000000DDF4390>
#   <matplotlib.axes._subplots.AxesSubplot object at 0x000000000DE68B00>
#   <matplotlib.axes._subplots.AxesSubplot object at 0x000000000DEEE2B0>
#   <matplotlib.axes._subplots.AxesSubplot object at 0x000000000DF63A20>
#   <matplotlib.axes._subplots.AxesSubplot object at 0x000000000E02A1D0>
#   <matplotlib.axes._subplots.AxesSubplot object at 0x000000000E09E940>]
#  [<matplotlib.axes._subplots.AxesSubplot object at 0x000000000E1430F0>
#   <matplotlib.axes._subplots.AxesSubplot object at 0x000000000E1FA860>
#   <matplotlib.axes._subplots.AxesSubplot object at 0x000000000E22FFD0>
#   <matplotlib.axes._subplots.AxesSubplot object at 0x000000000E2F2780>
#   <matplotlib.axes._subplots.AxesSubplot object at 0x000000000E327EF0>
#   <matplotlib.axes._subplots.AxesSubplot object at 0x000000000E3EF6A0>
#   <matplotlib.axes._subplots.AxesSubplot object at 0x000000000E423E10>
#   <matplotlib.axes._subplots.AxesSubplot object at 0x000000000E4E85C0>
#   <matplotlib.axes._subplots.AxesSubplot object at 0x000000000E51ED30>
#   <matplotlib.axes._subplots.AxesSubplot object at 0x000000000E5E14E0>
#   <matplotlib.axes._subplots.AxesSubplot object at 0x000000000E6DCC50>
#   <matplotlib.axes._subplots.AxesSubplot object at 0x000000000E71E400>
#   <matplotlib.axes._subplots.AxesSubplot object at 0x000000000E7D7B70>
#   <matplotlib.axes._subplots.AxesSubplot object at 0x000000000E85A320>
#   <matplotlib.axes._subplots.AxesSubplot object at 0x000000000E913A90>
#   <matplotlib.axes._subplots.AxesSubplot object at 0x000000000E9DA240>]
#  [<matplotlib.axes._subplots.AxesSubplot object at 0x000000000EA509B0>
#   <matplotlib.axes._subplots.AxesSubplot object at 0x000000000EAD3160>
#   <matplotlib.axes._subplots.AxesSubplot object at 0x000000000EB078D0>
#   <matplotlib.axes._subplots.AxesSubplot object at 0x000000000EB8D080>
#   <matplotlib.axes._subplots.AxesSubplot object at 0x000000000EC007F0>
#   <matplotlib.axes._subplots.AxesSubplot object at 0x000000000EC78F60>
#   <matplotlib.axes._subplots.AxesSubplot object at 0x000000000ED3F710>
#   <matplotlib.axes._subplots.AxesSubplot object at 0x000000000EDB4E80>
#   <matplotlib.axes._subplots.AxesSubplot object at 0x000000000EE37630>
#   <matplotlib.axes._subplots.AxesSubplot object at 0x000000000EEF0DA0>
#   <matplotlib.axes._subplots.AxesSubplot object at 0x000000000EF44550>
#   <matplotlib.axes._subplots.AxesSubplot object at 0x000000000EFFDCC0>
#   <matplotlib.axes._subplots.AxesSubplot object at 0x000000000F0F9470>
#   <matplotlib.axes._subplots.AxesSubplot object at 0x000000000F12EBE0>
#   <matplotlib.axes._subplots.AxesSubplot object at 0x000000000F171390>
#   <matplotlib.axes._subplots.AxesSubplot object at 0x000000000F229B00>]
#  [<matplotlib.axes._subplots.AxesSubplot object at 0x000000000F2AD2B0>
#   <matplotlib.axes._subplots.AxesSubplot object at 0x000000000F323A20>
#   <matplotlib.axes._subplots.AxesSubplot object at 0x000000000F3E81D0>
#   <matplotlib.axes._subplots.AxesSubplot object at 0x000000000F45D940>
#   <matplotlib.axes._subplots.AxesSubplot object at 0x000000000F5260F0>
#   <matplotlib.axes._subplots.AxesSubplot object at 0x000000000F59B860>
#   <matplotlib.axes._subplots.AxesSubplot object at 0x000000000F665FD0>
#   <matplotlib.axes._subplots.AxesSubplot object at 0x000000000F6E7780>
#   <matplotlib.axes._subplots.AxesSubplot object at 0x000000000F761EF0>
#   <matplotlib.axes._subplots.AxesSubplot object at 0x000000000F8256A0>
#   <matplotlib.axes._subplots.AxesSubplot object at 0x000000000F859E10>
#   <matplotlib.axes._subplots.AxesSubplot object at 0x000000000F89B5C0>
#   <matplotlib.axes._subplots.AxesSubplot object at 0x000000000F953D30>
#   <matplotlib.axes._subplots.AxesSubplot object at 0x000000000F9A74E0>
#   <matplotlib.axes._subplots.AxesSubplot object at 0x000000000FA60C50>
#   <matplotlib.axes._subplots.AxesSubplot object at 0x000000000FB26400>]
#  [<matplotlib.axes._subplots.AxesSubplot object at 0x000000000FB6CB70>
#   <matplotlib.axes._subplots.AxesSubplot object at 0x000000000FC32320>
#   <matplotlib.axes._subplots.AxesSubplot object at 0x000000000FCA8A90>
#   <matplotlib.axes._subplots.AxesSubplot object at 0x000000000FD3E240>
#   <matplotlib.axes._subplots.AxesSubplot object at 0x000000000FDF59B0>
#   <matplotlib.axes._subplots.AxesSubplot object at 0x000000000FE77160>
#   <matplotlib.axes._subplots.AxesSubplot object at 0x000000000FEAE8D0>
#   <matplotlib.axes._subplots.AxesSubplot object at 0x000000000FF32080>
#   <matplotlib.axes._subplots.AxesSubplot object at 0x000000000FFE97F0>
#   <matplotlib.axes._subplots.AxesSubplot object at 0x00000000100E5F60>
#   <matplotlib.axes._subplots.AxesSubplot object at 0x000000001016B710>
#   <matplotlib.axes._subplots.AxesSubplot object at 0x00000000101DFE80>
#   <matplotlib.axes._subplots.AxesSubplot object at 0x00000000102A6630>
#   <matplotlib.axes._subplots.AxesSubplot object at 0x00000000102DBDA0>
#   <matplotlib.axes._subplots.AxesSubplot object at 0x00000000103A0550>
#   <matplotlib.axes._subplots.AxesSubplot object at 0x0000000010459CC0>]
#  [<matplotlib.axes._subplots.AxesSubplot object at 0x000000001049B470>
#   <matplotlib.axes._subplots.AxesSubplot object at 0x00000000104CDBE0>
#   <matplotlib.axes._subplots.AxesSubplot object at 0x0000000010593390>
#   <matplotlib.axes._subplots.AxesSubplot object at 0x00000000105C6B00>
#   <matplotlib.axes._subplots.AxesSubplot object at 0x000000001068F2B0>
#   <matplotlib.axes._subplots.AxesSubplot object at 0x0000000010703A20>
#   <matplotlib.axes._subplots.AxesSubplot object at 0x000000001079B1D0>
#   <matplotlib.axes._subplots.AxesSubplot object at 0x0000000010853940>
#   <matplotlib.axes._subplots.AxesSubplot object at 0x00000000108E90F0>
#   <matplotlib.axes._subplots.AxesSubplot object at 0x00000000109A0860>
#   <matplotlib.axes._subplots.AxesSubplot object at 0x00000000109D6FD0>
#   <matplotlib.axes._subplots.AxesSubplot object at 0x0000000010A9A780>
#   <matplotlib.axes._subplots.AxesSubplot object at 0x0000000010B26EF0>
#   <matplotlib.axes._subplots.AxesSubplot object at 0x0000000010BE96A0>
#   <matplotlib.axes._subplots.AxesSubplot object at 0x0000000010C1DE10>
#   <matplotlib.axes._subplots.AxesSubplot object at 0x0000000010CE35C0>]
#  [<matplotlib.axes._subplots.AxesSubplot object at 0x0000000010D19D30>
#   <matplotlib.axes._subplots.AxesSubplot object at 0x0000000010DDC4E0>
#   <matplotlib.axes._subplots.AxesSubplot object at 0x0000000010E96C50>
#   <matplotlib.axes._subplots.AxesSubplot object at 0x0000000010EE9400>
#   <matplotlib.axes._subplots.AxesSubplot object at 0x0000000010FA2B70>
#   <matplotlib.axes._subplots.AxesSubplot object at 0x0000000011069320>
#   <matplotlib.axes._subplots.AxesSubplot object at 0x00000000110E2A90>
#   <matplotlib.axes._subplots.AxesSubplot object at 0x00000000111A5240>
#   <matplotlib.axes._subplots.AxesSubplot object at 0x000000001121B9B0>
#   <matplotlib.axes._subplots.AxesSubplot object at 0x00000000112A0160>
#   <matplotlib.axes._subplots.AxesSubplot object at 0x00000000112D58D0>
#   <matplotlib.axes._subplots.AxesSubplot object at 0x0000000011356080>
#   <matplotlib.axes._subplots.AxesSubplot object at 0x00000000113CE7F0>
#   <matplotlib.axes._subplots.AxesSubplot object at 0x0000000011486F60>
#   <matplotlib.axes._subplots.AxesSubplot object at 0x000000001150B710>
#   <matplotlib.axes._subplots.AxesSubplot object at 0x00000000115C3E80>]
#  [<matplotlib.axes._subplots.AxesSubplot object at 0x0000000011616630>
#   <matplotlib.axes._subplots.AxesSubplot object at 0x00000000116CFDA0>
#   <matplotlib.axes._subplots.AxesSubplot object at 0x00000000117D6550>
#   <matplotlib.axes._subplots.AxesSubplot object at 0x000000001180CCC0>
#   <matplotlib.axes._subplots.AxesSubplot object at 0x00000000118D0470>
#   <matplotlib.axes._subplots.AxesSubplot object at 0x0000000011904BE0>
#   <matplotlib.axes._subplots.AxesSubplot object at 0x0000000011946390>
#   <matplotlib.axes._subplots.AxesSubplot object at 0x0000000011A0FB00>
#   <matplotlib.axes._subplots.AxesSubplot object at 0x0000000011A942B0>
#   <matplotlib.axes._subplots.AxesSubplot object at 0x0000000011B08A20>
#   <matplotlib.axes._subplots.AxesSubplot object at 0x0000000011BCD1D0>
#   <matplotlib.axes._subplots.AxesSubplot object at 0x0000000011C42940>
#   <matplotlib.axes._subplots.AxesSubplot object at 0x0000000011CC80F0>
#   <matplotlib.axes._subplots.AxesSubplot object at 0x0000000011D50860>
#   <matplotlib.axes._subplots.AxesSubplot object at 0x0000000011E0BFD0>
#   <matplotlib.axes._subplots.AxesSubplot object at 0x0000000011E8D780>]
#  [<matplotlib.axes._subplots.AxesSubplot object at 0x0000000011F05EF0>
#   <matplotlib.axes._subplots.AxesSubplot object at 0x00000000124026A0>
#   <matplotlib.axes._subplots.AxesSubplot object at 0x0000000012435E10>
#   <matplotlib.axes._subplots.AxesSubplot object at 0x00000000124775C0>
#   <matplotlib.axes._subplots.AxesSubplot object at 0x000000001252FD30>
#   <matplotlib.axes._subplots.AxesSubplot object at 0x00000000125F64E0>
#   <matplotlib.axes._subplots.AxesSubplot object at 0x000000001262CC50>
#   <matplotlib.axes._subplots.AxesSubplot object at 0x0000000012733400>
#   <matplotlib.axes._subplots.AxesSubplot object at 0x00000000127ABB70>
#   <matplotlib.axes._subplots.AxesSubplot object at 0x000000001282D320>
#   <matplotlib.axes._subplots.AxesSubplot object at 0x00000000128A3A90>
#   <matplotlib.axes._subplots.AxesSubplot object at 0x000000001296A240>
#   <matplotlib.axes._subplots.AxesSubplot object at 0x00000000129DE9B0>
#   <matplotlib.axes._subplots.AxesSubplot object at 0x0000000012A61160>
#   <matplotlib.axes._subplots.AxesSubplot object at 0x0000000012A978D0>
#   <matplotlib.axes._subplots.AxesSubplot object at 0x0000000012B1A080>]
#  [<matplotlib.axes._subplots.AxesSubplot object at 0x0000000012BA37F0>
#   <matplotlib.axes._subplots.AxesSubplot object at 0x0000000012C5CF60>
#   <matplotlib.axes._subplots.AxesSubplot object at 0x0000000012CDF710>
#   <matplotlib.axes._subplots.AxesSubplot object at 0x0000000012D57E80>
#   <matplotlib.axes._subplots.AxesSubplot object at 0x0000000012E1B630>
#   <matplotlib.axes._subplots.AxesSubplot object at 0x0000000012E92DA0>
#   <matplotlib.axes._subplots.AxesSubplot object at 0x0000000012F48550>
#   <matplotlib.axes._subplots.AxesSubplot object at 0x0000000013001CC0>
#   <matplotlib.axes._subplots.AxesSubplot object at 0x0000000013041470>
#   <matplotlib.axes._subplots.AxesSubplot object at 0x0000000013077BE0>
#   <matplotlib.axes._subplots.AxesSubplot object at 0x000000001317F390>
#   <matplotlib.axes._subplots.AxesSubplot object at 0x00000000131B0B00>
#   <matplotlib.axes._subplots.AxesSubplot object at 0x00000000132782B0>
#   <matplotlib.axes._subplots.AxesSubplot object at 0x0000000013341A20>
#   <matplotlib.axes._subplots.AxesSubplot object at 0x00000000133FD1D0>
#   <matplotlib.axes._subplots.AxesSubplot object at 0x0000000013471940>]
#  [<matplotlib.axes._subplots.AxesSubplot object at 0x00000000134F70F0>
#   <matplotlib.axes._subplots.AxesSubplot object at 0x00000000135AD860>
#   <matplotlib.axes._subplots.AxesSubplot object at 0x00000000135E4FD0>
#   <matplotlib.axes._subplots.AxesSubplot object at 0x00000000136A8780>
#   <matplotlib.axes._subplots.AxesSubplot object at 0x0000000013762EF0>
#   <matplotlib.axes._subplots.AxesSubplot object at 0x00000000137A16A0>
#   <matplotlib.axes._subplots.AxesSubplot object at 0x00000000137D7E10>
#   <matplotlib.axes._subplots.AxesSubplot object at 0x000000001389B5C0>
#   <matplotlib.axes._subplots.AxesSubplot object at 0x0000000013912D30>
#   <matplotlib.axes._subplots.AxesSubplot object at 0x00000000139964E0>
#   <matplotlib.axes._subplots.AxesSubplot object at 0x0000000013A60C50>
#   <matplotlib.axes._subplots.AxesSubplot object at 0x0000000013AA3400>
#   <matplotlib.axes._subplots.AxesSubplot object at 0x0000000013B5DB70>
#   <matplotlib.axes._subplots.AxesSubplot object at 0x0000000013BDD320>
#   <matplotlib.axes._subplots.AxesSubplot object at 0x0000000013C98A90>
#   <matplotlib.axes._subplots.AxesSubplot object at 0x0000000013D1C240>]]
# Text(0.5,0.98,'Scatter matrix for all numerical values')
